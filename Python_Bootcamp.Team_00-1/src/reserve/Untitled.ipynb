# %%
import networkx as nx
import nx_altair as nxa


import json
with open("output.json", "r") as file:
    json_data = json.load(file)

G = nx.Graph(name="My Graph")
# def temp():
#     global G
#     G.add_edge('1', 1)
#     G.add_edge('1', 2)
#     G.add_edge('2', 3)
#     G.add_edge('2', 1)
#     G.add_edge('2', 2)
# temp()
# G.add_edge(1, 2, weight=3)
# G.add_edge(1, 4, weight=4)
# G.add_edge(1, 5, weight=4)
# G.add_edge(1, 6, weight=4)
# G.add_edge(2, 9, weight=4)
# G.add_edge(2, 7, weight=4)
# G.add_edge(2, 8, weight=4)
# G.add_edge(*e)
# G.add_edges_form([(1,2)])

def get_data(json_data):
    global G
    for key in json_data:
        node = key
        values = list(json_data[key])
        
        
        # print(node)
        # print(values)
        for value in values:
            # print(f"{node} and {value}")
            G.add_edge(node, value, weight=3)
        
        # get_data(json_data[key])

get_data(json_data)

# pos = nx.spring_layout(G)

viz = nxa.draw_networkx(G)
viz = nxa.

viz.interactive()
# Out:
# alt.LayerChart(...)
